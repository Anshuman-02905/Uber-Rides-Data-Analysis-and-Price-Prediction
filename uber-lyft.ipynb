# %% [markdown]
# # Uber Data Analysis

# %% [markdown]
# ### Defining the problem statement
# ### Collecting the data
# ##### Kaggle
# ### Exploratory data analysis
# ### Feature engineering
# ### Modelling
# ### Testing

# %% [markdown]
# ## 1. Defining the problem statement
# ________________________________________________________________________________________________________________________
# In this project, we study the data of Uber which is present in tabular format in which we use different libraries like numpy, pandas and matplotlib and different machine learning algorithms.
#
# We study different columns of the table and try to co-relate them with others and find a relation between those two.
#
# We try to find and analyze those key factors like date, month etc which helps Uber Company to enhance their business by focusing on those services and make required changes.

# %% [markdown]
# ## 2. Collecting the data
# ____________________________________________________________________________________________________________________________________________

# %%
import pandas as pd

uber_dataset = pd.read_csv(r"/kaggle/input/uber-and-lyft-dataset-boston-ma/rideshare_kaggle.csv")

# %%
uber_dataset.head(3)
# Out:
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
#
#               datetime          timezone            source    destination  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square  North Station
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square  North Station
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square  North Station
#
#   cab_type  ... precipIntensityMax uvIndexTime  temperatureMin  \
# 0     Lyft  ...             0.1276  1544979600           39.89
# 1     Lyft  ...             0.1300  1543251600           40.49
# 2     Lyft  ...             0.1064  1543338000           35.36
#
#    temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 0          1545012000           43.68          1544968800
# ...

# %%
uber_dataset.shape
# Out:
# (693071, 57)

# %%
uber_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           693071 non-null  object
#  1   timestamp                    693071 non-null  float64
#  2   hour                         693071 non-null  int64
#  3   day                          693071 non-null  int64
#  4   month                        693071 non-null  int64
#  5   datetime                     693071 non-null  object
#  6   timezone                     693071 non-null  object
#  7   source                       693071 non-null  object
#  8   destination                  693071 non-null  object
#  9   cab_type                     693071 non-null  object
#  10  product_id                   693071 non-null  object
#  11  name                         693071 non-null  object
# ...

# %%
uber_dataset.describe()
# Out:
#           timestamp           hour            day          month  \
# count  6.930710e+05  693071.000000  693071.000000  693071.000000
# mean   1.544046e+09      11.619137      17.794365      11.586684
# std    6.891925e+05       6.948114       9.982286       0.492429
# min    1.543204e+09       0.000000       1.000000      11.000000
# 25%    1.543444e+09       6.000000      13.000000      11.000000
# 50%    1.543737e+09      12.000000      17.000000      12.000000
# 75%    1.544828e+09      18.000000      28.000000      12.000000
# max    1.545161e+09      23.000000      30.000000      12.000000
#
#                price       distance  surge_multiplier       latitude  \
# count  637976.000000  693071.000000     693071.000000  693071.000000
# mean       16.545125       2.189430          1.013870      42.338172
# std         9.324359       1.138937          0.091641       0.047840
# min         2.500000       0.020000          1.000000      42.214800
# ...

# %%
uber_dataset.isnull().sum()
# Out:
# id                                 0
# timestamp                          0
# hour                               0
# day                                0
# month                              0
# datetime                           0
# timezone                           0
# source                             0
# destination                        0
# cab_type                           0
# product_id                         0
# name                               0
# price                          55095
# distance                           0
# surge_multiplier                   0
# latitude                           0
# longitude                          0
# temperature                        0
# apparentTemperature                0
# short_summary                      0
# long_summary                       0
# precipIntensity                    0
# precipProbability                  0
# humidity                           0
# windSpeed                          0
# ...

# %% [markdown]
# ## 4. Feature Engineering
# ---------------------------------------------------------------------
# What is a feature and why we need the engineering of it? Basically, all machine learning algorithms use some input data to create outputs. This input data comprise features, which are usually in the form of structured columns. Algorithms require features with some specific characteristic to work properly. Here, the need for feature engineering arises.
#
# I think feature engineering efforts mainly have two goals:
#
# Preparing the proper input dataset, compatible with the machine learning algorithm requirements.
#
# Improving the performance of machine learning models.
#
# According to a survey in Forbes, data scientists spend 80% of their time on data preparation:

# %% [markdown]
# ## PLOTTING

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Strip Plots

# %%
#Distribution across categories
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# First strip plot for 'cab_type'
sns.stripplot(data=uber_dataset, x='price', y='cab_type', hue='cab_type', ax=axes[0])
axes[0].legend([], [], frameon=False)
axes[0].set_title('Price vs Cab Type')

# Second strip plot for 'name'
sns.stripplot(data=uber_dataset, x='price', y='name', hue='name', ax=axes[1])
axes[1].legend([], [], frameon=False)
axes[1].set_title('Price vs Name')

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
#Distribution across categories
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# First strip plot for 'cab_type'
sns.stripplot(data=uber_dataset, x='distance', y='cab_type', hue='cab_type', ax=axes[0])
axes[0].legend([], [], frameon=False)
axes[0].set_title('Distance vs Cab Type')

# Second strip plot for 'name'
sns.stripplot(data=uber_dataset, x='distance', y='name', hue='name', ax=axes[1])
axes[1].legend([], [], frameon=False)
axes[1].set_title('Distance vs Name')

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Create a figure with 2 subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# First scatter plot for 'cab_type'
sns.scatterplot(data=uber_dataset, x='price', y='distance', hue='cab_type', ax=axes[0])
axes[0].set_title('Price vs Distance by Cab Type')
axes[0].legend(title='Cab Type')

# Second scatter plot for 'name'
sns.scatterplot(data=uber_dataset, x='price', y='distance', hue='name', ax=axes[1])
axes[1].set_title('Price vs Distance by Name')
axes[1].legend(title='Name')

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()
# Out:
# /tmp/ipykernel_33/491032221.py:15: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# First strip plot for 'icon'
sns.stripplot(data=uber_dataset, x='surge_multiplier', y='icon', hue='icon', ax=axes[0, 0])
axes[0, 0].legend(title='Icon', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[0, 0].set_title('Surge Multiplier vs Icon')

# Second strip plot for 'source'
sns.stripplot(data=uber_dataset, x='surge_multiplier', y='source', hue='source', ax=axes[0, 1])
axes[0, 1].legend(title='Source', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[0, 1].set_title('Surge Multiplier vs Source')

# Third strip plot for 'cab_type'
sns.stripplot(data=uber_dataset, x='surge_multiplier', y='cab_type', hue='cab_type', ax=axes[1, 0])
axes[1, 0].legend(title='Cab Type', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[1, 0].set_title('Surge Multiplier vs Cab Type')

# Fourth strip plot for 'name'
sns.stripplot(data=uber_dataset, x='surge_multiplier', y='name', hue='name', ax=axes[1, 1])
axes[1, 1].legend(title='Name', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[1, 1].set_title('Surge Multiplier vs Name')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with 2 subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# First strip plot for 'cab_type'
sns.stripplot(data=uber_dataset, x='hour', y='cab_type', hue='cab_type', ax=axes[0])
axes[0].legend(title='Cab Type', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[0].set_title('Hour vs Cab Type')

# Second strip plot for 'name'
sns.stripplot(data=uber_dataset, x='hour', y='name', hue='name', ax=axes[1])
axes[1].legend(title='Name', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[1].set_title('Hour vs Name')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.stripplot(data=uber_dataset, x='surge_multiplier', y='hour' ,hue='hour')
plt.legend([],[], frameon=False)
# Display the plot
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# ## Converting Timestamp to Datetime value

# %%
uber_dataset['timestamp'].head().astype(int)
# Out:
# 0    1544952607
# 1    1543284023
# 2    1543366822
# 3    1543553582
# 4    1543463360
# Name: timestamp, dtype: int64

# %%
from datetime import datetime
timestamp1 = 1544952607
timestamp2 = 1543284023
timestamp3 = 1543366822
timestamp4 = 1543553582
timestamp5 = 1543463360
dt_object1 = datetime.fromtimestamp(timestamp1)
dt_object2 = datetime.fromtimestamp(timestamp2)
dt_object3 = datetime.fromtimestamp(timestamp3)
dt_object4 = datetime.fromtimestamp(timestamp4)
dt_object5 = datetime.fromtimestamp(timestamp5)

print("dt_object =", dt_object1)
print("dt_object =", dt_object2)
print("dt_object =", dt_object3)
print("dt_object =", dt_object4)
print("dt_object =", dt_object5)
# Out:
# dt_object = 2018-12-16 09:30:07
# dt_object = 2018-11-27 02:00:23
# dt_object = 2018-11-28 01:00:22
# dt_object = 2018-11-30 04:53:02
# dt_object = 2018-11-29 03:49:20

# %%
aggregated_data = uber_dataset.groupby(['hour', 'name']).size().reset_index(name='count')
plt.figure(figsize=(12, 6))

sns.barplot(data=aggregated_data, x='hour', y='count', hue='name')
plt.title('Count of Rides by Hour and Cab Type')
plt.xlabel('Hour')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
aggregated_data_cab_type = uber_dataset.groupby(['hour', 'cab_type']).size().reset_index(name='count')

# Aggregate data for 'name'
aggregated_data_name = uber_dataset.groupby(['hour', 'name']).size().reset_index(name='count')

# Filter top 3 names for each hour
top_names = aggregated_data_name.groupby('hour').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)

# Create a figure with 2 subplots in one column
fig, axes = plt.subplots(2, 1, figsize=(12, 12))  # Adjusted the figure size for bigger plots

# First bar plot for 'cab_type'
sns.barplot(data=aggregated_data_cab_type, x='hour', y='count', hue='cab_type', ax=axes[0])
axes[0].legend(title='Cab Type', bbox_to_anchor=(1, 1), loc='upper left')
axes[0].set_title('Count of Rides by Hour and Cab Type')
axes[0].set_xlabel('Hour')
axes[0].set_ylabel('Count')

# Second bar plot for top 3 'name'
sns.barplot(data=top_names, x='hour', y='count', hue='name', ax=axes[1])
axes[1].legend(title='Name', bbox_to_anchor=(1, 1), loc='upper left')
axes[1].set_title('Top 3 Names by Hour')
axes[1].set_xlabel('Hour')
axes[1].set_ylabel('Count')



# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()
# Out:
# /tmp/ipykernel_33/2344411319.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_names = aggregated_data_name.groupby('hour').apply(lambda x: x.nlargest(3, 'count')).reset_index(drop=True)

# %%
uber_dataset['source'].value_counts().plot(kind='bar', figsize=(10,5), color='green')
# Out:
# <Axes: xlabel='source'>

# %%
uber_dataset['name'].value_counts().plot(kind='bar', figsize=(10,5), color='orange')
# Out:
# <Axes: xlabel='name'>

# %%
uber_dataset['icon'].value_counts().plot(kind='bar', figsize=(10,5), color='red')
# Out:
# <Axes: xlabel='icon'>

# %%
uber_dataset['uvIndex'].value_counts().plot(kind='bar', figsize=(10,5), color='brown')
# Out:
# <Axes: xlabel='uvIndex'>

# %%
uber_dataset['moonPhase'].value_counts().plot(kind='bar', figsize=(10,5), color='orange')
# Out:
# <Axes: xlabel='moonPhase'>

# %%
uber_dataset['precipProbability'].value_counts().plot(kind='bar', figsize=(10,5), color='blue')
# Out:
# <Axes: xlabel='precipProbability'>

# %% [markdown]
# # HANDING NULL VALUES

# %%
uber_dataset.isnull().sum()
# Out:
# id                                 0
# timestamp                          0
# hour                               0
# day                                0
# month                              0
# datetime                           0
# timezone                           0
# source                             0
# destination                        0
# cab_type                           0
# product_id                         0
# name                               0
# price                          55095
# distance                           0
# surge_multiplier                   0
# latitude                           0
# longitude                          0
# temperature                        0
# apparentTemperature                0
# short_summary                      0
# long_summary                       0
# precipIntensity                    0
# precipProbability                  0
# humidity                           0
# windSpeed                          0
# ...

# %%
uber_dataset['price'].median()
# Out:
# 13.5

# %%
uber_dataset["price"].fillna(13.5, inplace = True)
# Out:
# /tmp/ipykernel_33/1586457284.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   uber_dataset["price"].fillna(13.5, inplace = True)

# %%
uber_dataset.isnull().sum()
# Out:
# id                             0
# timestamp                      0
# hour                           0
# day                            0
# month                          0
# datetime                       0
# timezone                       0
# source                         0
# destination                    0
# cab_type                       0
# product_id                     0
# name                           0
# price                          0
# distance                       0
# surge_multiplier               0
# latitude                       0
# longitude                      0
# temperature                    0
# apparentTemperature            0
# short_summary                  0
# long_summary                   0
# precipIntensity                0
# precipProbability              0
# humidity                       0
# windSpeed                      0
# windGust                       0
# windGustTime                   0
# visibility                     0
# ...

# %%
'''print(uber_dataset['price'].isnull().sum())
len(uber_dataset.loc[uber_dataset['name']=='Taxi'])
uber_dataset.loc[uber_dataset['name']=='Taxi']

grouped = (
    uber_dataset.groupby(by=['source', 'destination', 'distance', 'surge_multiplier'])
    .agg(median_price=('price', 'median'))
    .reset_index()
    
    merged=pd.merge(uber_dataset,grouped,on=['source','destination','distance','surge_multiplier'],how='left')
    uber_dataset.loc[uber_dataset['name']=='Taxi','price']=merged.loc[merged['name']=='Taxi','median_price']

)'''
# Out:
# 55095

# %%
uber_dataset
# Out:
#                                           id     timestamp  hour  day  month  \
# 0       424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1       4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2       981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3       c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4       e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
# ...                                      ...           ...   ...  ...    ...
# 693066  616d3611-1820-450a-9845-a9ff304a4842  1.543708e+09    23    1     12
# 693067  633a3fc3-1f86-4b9e-9d48-2b7132112341  1.543708e+09    23    1     12
# 693068  64d451d0-639f-47a4-9b7c-6fd92fbd264f  1.543708e+09    23    1     12
# 693069  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e  1.543708e+09    23    1     12
# 693070  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda  1.543708e+09    23    1     12
#
# ...

# %%
uber_dataset  id datetime timezone
# Out:
#                                           id     timestamp  hour  day  month  \
# 0       424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1       4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2       981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3       c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4       e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
# ...                                      ...           ...   ...  ...    ...
# 693066  616d3611-1820-450a-9845-a9ff304a4842  1.543708e+09    23    1     12
# 693067  633a3fc3-1f86-4b9e-9d48-2b7132112341  1.543708e+09    23    1     12
# 693068  64d451d0-639f-47a4-9b7c-6fd92fbd264f  1.543708e+09    23    1     12
# 693069  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e  1.543708e+09    23    1     12
# 693070  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda  1.543708e+09    23    1     12
#
# ...

# %% [markdown]
# ## LABEL ENCODING

# %%
# Import label encoder 
from sklearn import preprocessing 
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
#uber_dataset['id']= label_encoder.fit_transform(uber_dataset['id']) 
#uber_dataset['datetime']= label_encoder.fit_transform(uber_dataset['datetime']) 
#uber_dataset['timezone']= label_encoder.fit_transform(uber_dataset['timezone'])
uber_dataset['destination']= label_encoder.fit_transform(uber_dataset['destination']) 
uber_dataset['product_id']= label_encoder.fit_transform(uber_dataset['product_id'])
uber_dataset['short_summary']= label_encoder.fit_transform(uber_dataset['short_summary'])
uber_dataset['long_summary']= label_encoder.fit_transform(uber_dataset['long_summary'])

uber_dataset['name']= label_encoder.fit_transform(uber_dataset['name'])

print("Class mapping of Name: ")
for i, item in enumerate(label_encoder.classes_):
    print(item, "-->", i)
    
uber_dataset['cab_type']= label_encoder.fit_transform(uber_dataset['cab_type'])

print("Class mapping of Source: ")
for i, item in enumerate(label_encoder.classes_):
    print(item, "-->", i)
    
uber_dataset['source']= label_encoder.fit_transform(uber_dataset['source'])

print("Class mapping of Source: ")
for i, item in enumerate(label_encoder.classes_):
    print(item, "-->", i)

uber_dataset['icon']= label_encoder.fit_transform(uber_dataset['icon'])

print("Class mapping of Icon: ")
for i, item in enumerate(label_encoder.classes_):
    print(item, "-->", i)
# Out:
# Class mapping of Name:
# Black --> 0
# Black SUV --> 1
# Lux --> 2
# Lux Black --> 3
# Lux Black XL --> 4
# Lyft --> 5
# Lyft XL --> 6
# Shared --> 7
# Taxi --> 8
# UberPool --> 9
# UberX --> 10
# UberXL --> 11
# WAV --> 12
# Class mapping of Source:
# Lyft --> 0
# Uber --> 1
# Class mapping of Source:
# Back Bay --> 0
# Beacon Hill --> 1
# Boston University --> 2
# Fenway --> 3
# Financial District --> 4
# Haymarket Square --> 5
# North End --> 6
# North Station --> 7
# Northeastern University --> 8
# South Station --> 9
# Theatre District --> 10
# West End --> 11
# Class mapping of Icon:
#  clear-day  --> 0
#  clear-night  --> 1
#  cloudy  --> 2
#  fog  --> 3
#  partly-cloudy-day  --> 4
#  partly-cloudy-night  --> 5
#  rain  --> 6

# %%
month_mapping = {11: 0, 12: 1}
uber_dataset['month'] = uber_dataset['month'].map(month_mapping)
surge_multiplier_mapping = {1.: 0, 1.25: 1, 1.5: 2, 1.75: 3, 2.:4,2.5:5,3.:6}
uber_dataset['surge_multiplier'] = uber_dataset['surge_multiplier'].map(surge_multiplier_mapping)

# %%
uber_dataset
# Out:
#             id     timestamp  hour  day  month  datetime  timezone  source  \
# 0       179271  1.544953e+09     9   16      1     25351         0       5
# 1       205021  1.543284e+09     2   27      0       961         0       5
# 2       411506  1.543367e+09     1   28      0      2534         0       5
# 3       527263  1.543554e+09     4   30      0      6988         0       5
# 4       606526  1.543463e+09     3   29      0      4400         0       5
# ...        ...           ...   ...  ...    ...       ...       ...     ...
# 693066  263466  1.543708e+09    23    1      1     11456         0      11
# 693067  268325  1.543708e+09    23    1      1     11456         0      11
# 693068  272709  1.543708e+09    23    1      1     11456         0      11
# 693069  309823  1.543708e+09    23    1      1     11456         0      11
# 693070  628118  1.543708e+09    23    1      1     11456         0      11
#
#         destination  cab_type  product_id  name  price  distance  \
# ...

# %%
uber_dataset.dtypes
# Out:
# id                               int64
# timestamp                      float64
# hour                             int64
# day                              int64
# month                            int64
# datetime                         int64
# timezone                         int64
# source                           int64
# destination                      int64
# cab_type                         int64
# product_id                       int64
# name                             int64
# price                          float64
# distance                       float64
# surge_multiplier               float64
# latitude                       float64
# longitude                      float64
# temperature                    float64
# apparentTemperature            float64
# short_summary                    int64
# long_summary                     int64
# precipIntensity                float64
# precipProbability              float64
# humidity                       float64
# ...

# %%
uber_dataset.head()
# Out:
#        id     timestamp  hour  day  month  datetime  timezone  source  \
# 0  179271  1.544953e+09     9   16     12     25351         0       5
# 1  205021  1.543284e+09     2   27     11       961         0       5
# 2  411506  1.543367e+09     1   28     11      2534         0       5
# 3  527263  1.543554e+09     4   30     11      6988         0       5
# 4  606526  1.543463e+09     3   29     11      4400         0       5
#
#    destination  cab_type  ...  precipIntensityMax  uvIndexTime  \
# 0            7         0  ...              0.1276   1544979600
# 1            7         0  ...              0.1300   1543251600
# 2            7         0  ...              0.1064   1543338000
# 3            7         0  ...              0.0000   1543507200
# 4            7         0  ...              0.0001   1543420800
#
#    temperatureMin  temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 0           39.89          1545012000           43.68          1544968800
# ...

# %%
corelation=uber_dataset.corr()

# %%
corelation
# Out:
#                                    id  timestamp      hour       day  \
# id                           1.000000   0.001034 -0.000012 -0.001298
# timestamp                    0.001034   1.000000 -0.028004 -0.341292
# hour                        -0.000012  -0.028004  1.000000  0.066090
# day                         -0.001298  -0.341292  0.066090  1.000000
# month                        0.001436   0.771182 -0.079379 -0.861306
# datetime                     0.001070   0.967438 -0.031359 -0.474329
# timezone                          NaN        NaN       NaN       NaN
# source                      -0.001737  -0.000531  0.002685 -0.000760
# destination                 -0.000106  -0.001181 -0.004190 -0.001813
# cab_type                    -0.001917   0.000854 -0.001257  0.001868
# product_id                   0.002042  -0.001084  0.001402 -0.001121
# name                        -0.000951   0.001053  0.000158  0.000993
# price                        0.001060   0.000742  0.000509 -0.000587
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
filtered_correlation_matrix = corelation[corelation.abs() >= 0.25].dropna(axis=1, how='all').dropna(axis=0, how='all')
plt.figure(figsize=(30, 30))

# Draw the heatmap with the filtered correlation matrix
sns.heatmap(filtered_correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1, center=0)

# Add title
plt.title('Filtered Correlation Matrix Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# ### BY corelation matrix (label encoded)-Name of cab and distance is most corelated with price but Name is not ordered therefore only distance is to be considered

# %%
uber_dataset['price'].median()
# Out:
# 13.5

# %%
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.feature_selection import RFE

# %%
[ 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
       'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
       'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
       'apparentTemperature', 'short_summary', 'long_summary',
       'precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
       'windGust', 'windGustTime', 'visibility', 'temperatureHigh',
       'temperatureHighTime', 'temperatureLow', 'temperatureLowTime',
       'apparentTemperatureHigh', 'apparentTemperatureHighTime',
       'apparentTemperatureLow', 'apparentTemperatureLowTime', 'icon',
       'dewPoint', 'pressure', 'windBearing', 'cloudCover', 'uvIndex',
       'visibility.1', 'ozone', 'sunriseTime', 'sunsetTime', 'moonPhase',
       'precipIntensityMax', 'uvIndexTime', 'temperatureMin',
       'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
       'apparentTemperatureMin', 'apparentTemperatureMinTime',
       'apparentTemperatureMax', 'apparentTemperatureMaxTime']
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
#        'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'apparentTemperature', 'short_summary', 'long_summary',
#        'precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
#        'windGust', 'windGustTime', 'visibility', 'temperatureHigh',
#        'temperatureHighTime', 'temperatureLow', 'temperatureLowTime',
#        'apparentTemperatureHigh', 'apparentTemperatureHighTime',
#        'apparentTemperatureLow', 'apparentTemperatureLowTime', 'icon',
#        'dewPoint', 'pressure', 'windBearing', 'cloudCover', 'uvIndex',
#        'visibility.1', 'ozone', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensityMax', 'uvIndexTime', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
# ...

# %%
X = uber_dataset.drop(['price','id'],axis=1)
y = uber_dataset['price']
X.head()
# Out:
#       timestamp  hour  day  month  datetime  timezone  source  destination  \
# 0  1.544953e+09     9   16      1     25351         0       5            7
# 1  1.543284e+09     2   27      0       961         0       5            7
# 2  1.543367e+09     1   28      0      2534         0       5            7
# 3  1.543554e+09     4   30      0      6988         0       5            7
# 4  1.543463e+09     3   29      0      4400         0       5            7
#
#    cab_type  product_id  name  distance  surge_multiplier  latitude  \
# 0         0           8     7      0.44                 0   42.2148
# 1         0          12     2      0.44                 0   42.2148
# 2         0           7     5      0.44                 0   42.2148
# 3         0          10     4      0.44                 0   42.2148
# 4         0          11     6      0.44                 0   42.2148
#
#    longitude  temperature  apparentTemperature  short_summary  long_summary  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_scaled=scaler.fit_transform(X)

# %%
y.head()
# Out:
# 0     5.0
# 1    11.0
# 2     7.0
# 3    26.0
# 4     9.0
# Name: price, dtype: float64

# %%
X_scaled.shape
# Out:
# (693071, 56)

# %%
y.value_counts().plot(kind='bar',figsize=(30,8),color='red')
# Out:
# <Axes: xlabel='price'>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2, random_state = 42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (554456, 55)
# (138615, 55)
# (554456,)
# (138615,)

# %%
#Creating model
reg = LinearRegression()
#Fitting training data
reg = reg.fit(X_train, y_train)
reg.score(X_test, y_test)

# %%
reg.score(X_test, y_test)
# Out:
# 0.5260080677593377

# %%
from sklearn.ensemble import RandomForestRegressor

# Creating a Random Forest model
reg = RandomForestRegressor()

# Fitting the training data
reg.fit(X_train, y_train)

# Evaluating the model's score (R-squared value)
score = reg.score(X_test, y_test)

# Print the score
print("Model R^2 Score:", score)
# Out:
# Model R^2 Score: 0.9614463873104584

# %%
from sklearn.tree import DecisionTreeRegressor
decision = DecisionTreeRegressor(random_state = 0)  
decision.fit(X_train , y_train) 
score = decision.score(X_test, y_test)

print("Model Decision tree R^2 Score:", score)

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5)
clf.fit(X_train, y_train)

score = clf.score(X_test, y_test)

# Print the score
print("Model GradientBoost R^2 Score:", score)
# Out:
# Model GradientBoost R^2 Score: 0.9681317719858539

# %%
y_test_array = np.array(y_test)

# %%
predictions = clf.predict(X_test)
sns.regplot(x=y_test_array,y=predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
## MEASURE THE RESIDUALS generally around 0 should be
sns.distplot(y_test_array - predictions,bins=50)
# Out:
# /tmp/ipykernel_33/4089671053.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test_array - predictions,bins=50)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
from sklearn import metrics
print('MAE :'," ", metrics.mean_absolute_error(y_test_array,predictions))
print('MSE :'," ", metrics.mean_squared_error(y_test_array,predictions))
print('RMAE :'," ", np.sqrt(metrics.mean_squared_error(y_test_array,predictions)))
# Out:
# MAE :   1.0154264146218972
# MSE :   2.5684243560647118
# RMAE :   1.6026304490008643

# %% [markdown]
# ## OPTIMAZTION

# %%
# !pip install optuna

# %%
import optuna
from sklearn import ensemble
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# Define the objective function
def objective(trial):
    # Suggest hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 100, 500)
    max_depth = trial.suggest_int('max_depth', 3, 10)
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.2)
    
    # Create and train the model
    model = ensemble.GradientBoostingRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate
    )
    model.fit(X_train, y_train)
    
    # Make predictions and calculate the R^2 score
    predictions = model.predict(X_test)
    score = r2_score(y_test, predictions)
    
    return score

# Create an Optuna study and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)  # You can adjust the number of trials

# Print the best hyperparameters and best score
print("Best hyperparameters:", study.best_params)
print("Best R^2 score:", study.best_value)

# Train the final model with the best hyperparameters
best_params = study.best_params
final_model = ensemble.GradientBoostingRegressor(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    learning_rate=best_params['learning_rate']
)
final_model.fit(X_train, y_train)
final_score = final_model.score(X_test, y_test)
print("Final Model GradientBoost R^2 Score:", final_score)
# Out:
# [I 2024-09-08 04:28:25,024] A new study created in memory with name: no-name-40b014de-d34e-4f7f-b248-231b4097c217
# /tmp/ipykernel_33/2275193048.py:11: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.2)
# [I 2024-09-08 04:48:56,519] Trial 0 finished with value: 0.9672820559026594 and parameters: {'n_estimators': 187, 'max_depth': 5, 'learning_rate': 0.1022688194414465}. Best is trial 0 with value: 0.9672820559026594.
# /tmp/ipykernel_33/2275193048.py:11: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.2)
# ...

# %%
{'n_estimators': 217, 'max_depth': 9, 'learning_rate': 0.10973044870736459}

# %%
'''BEST PARAMETERS with  R2 value as '0.9699032795940326 '''
